# %%
import pandas as pd

# %%
x=pd.read_csv("titanic.csv")
x
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 6            898         1       3
# 7            899         0       2
# 8            900         1       3
# 9            901         0       3
# 10           902         0       3
# 11           903         0       1
# 12           904         1       1
# 13           905         0       2
# 14           906         1       1
# 15           907         1       2
# 16           908         0       2
# 17           909         0       3
# 18           910         1       3
# 19           911         1       3
# 20           912         0       1
# 21           913         0       3
# 22           914         1       1
# 23           915         0       1
# 24           916         1       1
# ...

# %%
#Print 5 records
print(x.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(type(x))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
x.shape  #shape
# Out:
# (418, 12)

# %%
x.columns  #column names
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
x.info()  #get more info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
# PassengerId    418 non-null int64
# Survived       418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
#if we want specific column
Age_x=x["Age"]
Age_x
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
# 5      14.0
# 6      30.0
# 7      26.0
# 8      18.0
# 9      21.0
# 10      NaN
# 11     46.0
# 12     23.0
# 13     63.0
# 14     47.0
# 15     24.0
# 16     35.0
# 17     21.0
# 18     27.0
# 19     45.0
# 20     55.0
# 21      9.0
# 22      NaN
# 23     21.0
# 24     48.0
# 25     50.0
# 26     22.0
# 27     22.5
# 28     41.0
# 29      NaN
#        ...
# 388    21.0
# 389     6.0
# 390    23.0
# 391    51.0
# 392    13.0
# 393    47.0
# 394    29.0
# 395    18.0
# 396    24.0
# 397    48.0
# 398    22.0
# 399    31.0
# 400    30.0
# 401    38.0
# 402    22.0
# 403    17.0
# 404    43.0
# 405    20.0
# 406    23.0
# 407    50.0
# 408     NaN
# 409     3.0
# 410     NaN
# 411    37.0
# 412    28.0
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
Age_x.head()
# Out:
# 0    34.5
# 1    47.0
# 2    62.0
# 3    27.0
# 4    22.0
# Name: Age, dtype: float64

# %%
Age_x.tail()
# Out:
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, dtype: float64

# %%
subset=x[['Name','Age','Sex']]
subset
# Out:
#                                                   Name   Age     Sex
# 0                                     Kelly, Mr. James  34.5    male
# 1                     Wilkes, Mrs. James (Ellen Needs)  47.0  female
# 2                            Myles, Mr. Thomas Francis  62.0    male
# 3                                     Wirz, Mr. Albert  27.0    male
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0  female
# 5                           Svensson, Mr. Johan Cervin  14.0    male
# 6                                 Connolly, Miss. Kate  30.0  female
# 7                         Caldwell, Mr. Albert Francis  26.0    male
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)  18.0  female
# 9                              Davies, Mr. John Samuel  21.0    male
# 10                                    Ilieff, Mr. Ylio   NaN    male
# 11                          Jones, Mr. Charles Cresson  46.0    male
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  23.0  female
# ...

# %%
#to get first row
x.loc[0]
# Out:
# PassengerId                 892
# Survived                      0
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %%
#min,max,mean,median,std
fare_x=x["Fare"]
fare_x
mean=fare_x.mean()
print(mean)
std=fare_x.std()
print(std)
median=fare_x.median()
print(median)
min=fare_x.min()
print(min)
max=fare_x.max()
print(max)
mode=fare_x.mode()
print(mode)
# Out:
# 35.6271884892086
# 55.90757617997383
# 14.4542
# 0.0
# 512.3292
# 0    7.75
# dtype: float64

# %%
#Transpose of the series
x.describe().T
# Out:
#              count         mean         std     min       25%        50%  \
# PassengerId  418.0  1100.500000  120.810458  892.00  996.2500  1100.5000
# Survived     418.0     0.363636    0.481622    0.00    0.0000     0.0000
# Pclass       418.0     2.265550    0.841838    1.00    1.0000     3.0000
# Age          332.0    30.272590   14.181209    0.17   21.0000    27.0000
# SibSp        418.0     0.447368    0.896760    0.00    0.0000     0.0000
# Parch        418.0     0.392344    0.981429    0.00    0.0000     0.0000
# Fare         417.0    35.627188   55.907576    0.00    7.8958    14.4542
#
#                  75%        max
# PassengerId  1204.75  1309.0000
# Survived        1.00     1.0000
# Pclass          3.00     3.0000
# Age            39.00    76.0000
# SibSp           1.00     8.0000
# Parch           0.00     9.0000
# Fare           31.50   512.3292

# %%
#Transpose of the series
x.T
# Out:
#                           0                                 1    \
# PassengerId               892                               893
# Survived                    0                                 1
# Pclass                      3                                 3
# Name         Kelly, Mr. James  Wilkes, Mrs. James (Ellen Needs)
# Sex                      male                            female
# Age                      34.5                                47
# SibSp                       0                                 1
# Parch                       0                                 0
# Ticket                 330911                            363272
# Fare                   7.8292                                 7
# Cabin                     NaN                               NaN
# Embarked                    Q                                 S
#
#                                    2                 3    \
# PassengerId                        894               895
# ...

# %%
#to make title as a index 
x=pd.read_csv('titanic.csv',index_col="Name")
x
# Out:
#                                                     PassengerId  Survived  \
# Name
# Kelly, Mr. James                                            892         0
# Wilkes, Mrs. James (Ellen Needs)                            893         1
# Myles, Mr. Thomas Francis                                   894         0
# Wirz, Mr. Albert                                            895         0
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)                896         1
# Svensson, Mr. Johan Cervin                                  897         0
# Connolly, Miss. Kate                                        898         1
# Caldwell, Mr. Albert Francis                                899         0
# Abrahim, Mrs. Joseph (Sophie Halaut Easu)                   900         1
# Davies, Mr. John Samuel                                     901         0
# Ilieff, Mr. Ylio                                            902         0
# Jones, Mr. Charles Cresson                                  903         0
# ...

# %%
#check null value & after give count of null values
x.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
y=x.dropna()
y
# Out:
#                                                     PassengerId  Survived  \
# Name
# Snyder, Mrs. John Pillsbury (Nelle Stevenson)               904         1
# Chaffee, Mrs. Herbert Fuller (Carrie Constance ...          906         1
# Ryerson, Mrs. Arthur Larned (Emily Maria Borie)             916         1
# Ostby, Miss. Helene Ragnhild                                918         1
# Brady, Mr. John Bertram                                     920         0
# Mock, Mr. Philipp Edmund                                    926         0
# Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)            936         1
# Chevre, Mr. Paul Romaine                                    938         0
# Bucknell, Mrs. William Robert (Emma Eliza Ward)             940         1
# Smith, Mr. Lucien Philip                                    942         0
# Fortune, Miss. Ethel Flora                                  945         1
# Abelseth, Mr. Olaus Jorgensen                               949         0
# ...

# %%
y.shape
# Out:
# (87, 11)

# %%
#check the null values of cabin
cabin=x['Cabin']
cabin
# Out:
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 B45
# 13                 NaN
# 14                 E31
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24     B57 B59 B63 B66
# 25                 NaN
# 26                 B36
# 27                 NaN
# 28                 A21
# 29                 NaN
#             ...
# 388                NaN
# 389                NaN
# 390                B24
# 391                D28
# 392                NaN
# 393                NaN
# 394                NaN
# 395                C31
# 396                NaN
# ...

# %%
cabin
# Out:
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 B45
# 13                 NaN
# 14                 E31
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24     B57 B59 B63 B66
# 25                 NaN
# 26                 B36
# 27                 NaN
# 28                 A21
# 29                 NaN
#             ...
# 388                NaN
# 389                NaN
# 390                B24
# 391                D28
# 392                NaN
# 393                NaN
# 394                NaN
# 395                C31
# 396                NaN
# ...

# %%
y.median()
# Out:
# PassengerId    1094.0000
# Survived          1.0000
# Pclass            1.0000
# Age              39.0000
# SibSp             1.0000
# Parch             0.0000
# Fare             71.2833
# dtype: float64

# %%
ymean=y.mean()
ymean
# Out:
# PassengerId    1102.712644
# Survived          0.505747
# Pclass            1.137931
# Age              39.247126
# SibSp             0.597701
# Parch             0.482759
# Fare             98.109198
# dtype: float64

# %%
xy=pd.read_csv("titanic.csv")
xy
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 6            898         1       3
# 7            899         0       2
# 8            900         1       3
# 9            901         0       3
# 10           902         0       3
# 11           903         0       1
# 12           904         1       1
# 13           905         0       2
# 14           906         1       1
# 15           907         1       2
# 16           908         0       2
# 17           909         0       3
# 18           910         1       3
# 19           911         1       3
# 20           912         0       1
# 21           913         0       3
# 22           914         1       1
# 23           915         0       1
# 24           916         1       1
# ...

# %%
#to fill the null values for age

age=xy['Age']
age
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
# 5      14.0
# 6      30.0
# 7      26.0
# 8      18.0
# 9      21.0
# 10      NaN
# 11     46.0
# 12     23.0
# 13     63.0
# 14     47.0
# 15     24.0
# 16     35.0
# 17     21.0
# 18     27.0
# 19     45.0
# 20     55.0
# 21      9.0
# 22      NaN
# 23     21.0
# 24     48.0
# 25     50.0
# 26     22.0
# 27     22.5
# 28     41.0
# 29      NaN
#        ...
# 388    21.0
# 389     6.0
# 390    23.0
# 391    51.0
# 392    13.0
# 393    47.0
# 394    29.0
# 395    18.0
# 396    24.0
# 397    48.0
# 398    22.0
# 399    31.0
# 400    30.0
# 401    38.0
# 402    22.0
# 403    17.0
# 404    43.0
# 405    20.0
# 406    23.0
# 407    50.0
# 408     NaN
# 409     3.0
# 410     NaN
# 411    37.0
# 412    28.0
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
age.mean()
# Out:
# 30.272590361445783

# %%
age.median()
# Out:
# 30.272590361445783

# %%
agemean=age.mean()
agemean
# Out:
# 30.272590361445783

# %%
age.fillna(agemean,inplace=True)

# %%
xy.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
subset=xy.iloc[100:200] #to filter from 100 t0 200
subset
# Out:
#      PassengerId  Survived  Pclass  \
# 100          992         1       1
# 101          993         0       2
# 102          994         0       3
# 103          995         0       3
# 104          996         1       3
# 105          997         0       3
# 106          998         0       3
# 107          999         0       3
# 108         1000         0       3
# 109         1001         0       2
# 110         1002         0       2
# 111         1003         1       3
# 112         1004         1       1
# 113         1005         1       3
# 114         1006         1       1
# 115         1007         0       3
# 116         1008         0       3
# 117         1009         1       3
# 118         1010         0       1
# 119         1011         1       2
# 120         1012         1       2
# 121         1013         0       3
# 122         1014         1       1
# 123         1015         0       3
# 124         1016         0       3
# ...

# %%
#to get the specific detail
xy[(xy['Age']>=32)&(xy['Age']<=36)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 16           908         0       2
# 32           924         1       3
# 49           941         1       3
# 56           948         0       3
# 59           951         1       1
# 61           953         0       2
# 74           966         1       1
# 75           967         0       1
# 99           991         0       3
# 112         1004         1       1
# 118         1010         0       1
# 122         1014         1       1
# 130         1022         0       3
# 141         1033         1       1
# 153         1045         1       3
# 178         1070         1       2
# 190         1082         0       2
# 195         1087         0       3
# 206         1098         1       3
# 208         1100         1       1
# 210         1102         0       3
# 229         1121         0       2
# 254         1146         0       3
# 285         1177         0       3
# ...
