# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.size
# Out:
# 750

# %%
df.info
# Out:
# <bound method DataFrame.info of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
mdf=pd.read_csv("Movie-Data.csv")

# %%
mdf
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# mdf.columns

# %%
mdf.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
mdf.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                   10
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
mdf1=mdf.dropna()

# %%
mdf1
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# 5       6           The Great Wall  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 985   986            Your Highness  Adventure,Comedy,Fantasy
# 986   987      Final Destination 5           Horror,Thriller
# 987   988             Endless Love             Drama,Romance
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 0    A group of intergalactic criminals are forced ...          James Gunn
# 1    Following clues to the origin of mankind, a te...        Ridley Scott
# ...

# %%
mdf.shape
# Out:
# (1000, 12)

# %%
mdf1.shape
# Out:
# (830, 12)

# %%
mdf1=mdf.dropna(inplace=True)
mdf.shape
# Out:
# (830, 12)

# %%
df=pd.read_csv("Movie-Data.csv")
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                   10
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
tin=pd.read_csv("titanic.csv")

# %%
tin
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
tin.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
t=tin['Age']
t
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
type(t)
# Out:
# pandas.core.series.Series

# %%
t.mean()
# Out:
# 30.272590361445783

# %%
t.fillna(t.mean,inplace=True)

# %%
t.isnull().sum()
# Out:
# 0

# %%
movie=pd.read_csv('Movie-Data.csv')

# %%
movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movie.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                   10
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
rev=movie['Revenue (Millions)']
rev
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
yea=movie['Year']
yea
# Out:
# 0      2014.0
# 1      2012.0
# 2      2016.0
# 3         NaN
# 4      2016.0
#         ...
# 995       NaN
# 996       NaN
# 997    2008.0
# 998    2014.0
# 999    2016.0
# Name: Year, Length: 1000, dtype: float64

# %%
rev.mean()
# Out:
# 82.95637614678897

# %%
yea.mean()
# Out:
# 2012.7919191919193

# %%
rev.fillna(rev.mean,inplace=True)

# %%
movie.isnull().sum()
# Out:
# Rank                   0
# Title                  0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                  10
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %%
yea=yea.fillna(yea.mean,inplace=True)

# %%
movie.isnull().sum()
# Out:
# Rank                   0
# Title                  0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %%
movie.shape
# Out:
# (1000, 12)

# %%
movie1=movie.dropna()
movie1.shape
# Out:
# (936, 12)

# %%
movie.shape
# Out:
# (1000, 12)

# %%
movie1=movie.dropna(inplace=True)
movie.shape
# Out:
# (936, 12)

# %%
movies=pd.read_csv("Movie-Data.csv")
movies
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movies=pd.read_csv("Movie-Data.csv",index_col='Title')
movies
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
subset=movies[['Genre','Director']]
subset
# Out:
#                                             Genre              Director
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi            James Gunn
# Prometheus               Adventure,Mystery,Sci-Fi          Ridley Scott
# Split                             Horror,Thriller    M. Night Shyamalan
# Sing                      Animation,Comedy,Family  Christophe Lourdelet
# Suicide Squad            Action,Adventure,Fantasy            David Ayer
# ...                                           ...                   ...
# Secret in Their Eyes          Crime,Drama,Mystery             Billy Ray
# Hostel: Part II                            Horror              Eli Roth
# Step Up 2: The Streets        Drama,Music,Romance            Jon M. Chu
# Search Party                     Adventure,Comedy        Scot Armstrong
# Nine Lives                  Comedy,Family,Fantasy      Barry Sonnenfeld
#
# [1000 rows x 2 columns]

# %%
movies.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
sub1=movies['Genre']
sub1
# Out:
# Title
# Guardians of the Galaxy     Action,Adventure,Sci-Fi
# Prometheus                 Adventure,Mystery,Sci-Fi
# Split                               Horror,Thriller
# Sing                        Animation,Comedy,Family
# Suicide Squad              Action,Adventure,Fantasy
#                                      ...
# Secret in Their Eyes            Crime,Drama,Mystery
# Hostel: Part II                              Horror
# Step Up 2: The Streets          Drama,Music,Romance
# Search Party                       Adventure,Comedy
# Nine Lives                    Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
su1=movies[['Genre','Director']]
su1
# Out:
#                                             Genre              Director
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi            James Gunn
# Prometheus               Adventure,Mystery,Sci-Fi          Ridley Scott
# Split                             Horror,Thriller    M. Night Shyamalan
# Sing                      Animation,Comedy,Family  Christophe Lourdelet
# Suicide Squad            Action,Adventure,Fantasy            David Ayer
# ...                                           ...                   ...
# Secret in Their Eyes          Crime,Drama,Mystery             Billy Ray
# Hostel: Part II                            Horror              Eli Roth
# Step Up 2: The Streets        Drama,Music,Romance            Jon M. Chu
# Search Party                     Adventure,Comedy        Scot Armstrong
# Nine Lives                  Comedy,Family,Fantasy      Barry Sonnenfeld
#
# [1000 rows x 2 columns]

# %%
subset1=movies.loc["Split"]
subset1
# Out:
# Rank                                                                  3
# Genre                                                   Horror,Thriller
# Description           Three girls are kidnapped by a man with a diag...
# Director                                             M. Night Shyamalan
# Actors                James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Year                                                               2016
# Runtime (Minutes)                                                   117
# Rating                                                              7.3
# Votes                                                            157606
# Revenue (Millions)                                               138.12
# Metascore                                                            62
# Name: Split, dtype: object

# %%
iri=pd.read_csv("iris.csv")
iri
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iri.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
set=iri['sepal.length']
set
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal.length, Length: 150, dtype: float64

# %%
subset=iri.loc[1]
subset
# Out:
# sepal.length       4.9
# sepal.width          3
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 1, dtype: object

# %%
subset=iri.loc[145]
subset
# Out:
# sepal.length          6.7
# sepal.width             3
# petal.length          5.2
# petal.width           2.3
# variety         Virginica
# Name: 145, dtype: object

# %%
subset=iri.iloc[145]
subset
# Out:
# sepal.length          6.7
# sepal.width             3
# petal.length          5.2
# petal.width           2.3
# variety         Virginica
# Name: 145, dtype: object

# %%
filt=iri.loc[100:145]
filt
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %%
iri=pd.read_csv("iris.csv",index_col='sepal.length')
iri
# Out:
#               sepal.width  petal.length  petal.width    variety
# sepal.length
# 5.1                   3.5           1.4          0.2     Setosa
# 4.9                   3.0           1.4          0.2     Setosa
# 4.7                   3.2           1.3          0.2     Setosa
# 4.6                   3.1           1.5          0.2     Setosa
# 5.0                   3.6           1.4          0.2     Setosa
# ...                   ...           ...          ...        ...
# 6.7                   3.0           5.2          2.3  Virginica
# 6.3                   2.5           5.0          1.9  Virginica
# 6.5                   3.0           5.2          2.0  Virginica
# 6.2                   3.4           5.4          2.3  Virginica
# 5.9                   3.0           5.1          1.8  Virginica
#
# [150 rows x 4 columns]

# %%
subset=iri.loc[6.5]
subset
# Out:
#               sepal.width  petal.length  petal.width     variety
# sepal.length
# 6.5                   2.8           4.6          1.5  Versicolor
# 6.5                   3.0           5.8          2.2   Virginica
# 6.5                   3.2           5.1          2.0   Virginica
# 6.5                   3.0           5.5          1.8   Virginica
# 6.5                   3.0           5.2          2.0   Virginica

# %%
movies=pd.read_csv("Movie-Data.csv")
movies
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movies['Year']==2012
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Year, Length: 1000, dtype: bool

# %%
#to get detail
det=movies[movies['Year']==2012]
det
# Out:
#      Rank                       Title                      Genre  \
# 1       2                  Prometheus   Adventure,Mystery,Sci-Fi
# 76     77                The Avengers              Action,Sci-Fi
# 124   125       The Dark Knight Rises            Action,Thriller
# 135   136  The Place Beyond the Pines       Crime,Drama,Thriller
# 144   145            Django Unchained              Drama,Western
# ..    ...                         ...                        ...
# 891   892                  This Is 40             Comedy,Romance
# 916   917           The Expendables 2  Action,Adventure,Thriller
# 929   930                  The Master                      Drama
# 957   958                End of Watch       Crime,Drama,Thriller
# 972   973                Rock of Ages       Comedy,Drama,Musical
#
#                                            Description              Director  \
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
det=movies[movies['Director']=='Ridley Scott']
det
# Out:
#      Rank                   Title                     Genre  \
# 1       2              Prometheus  Adventure,Mystery,Sci-Fi
# 102   103             The Martian    Adventure,Drama,Sci-Fi
# 387   388              Robin Hood    Action,Adventure,Drama
# 470   471       American Gangster     Biography,Crime,Drama
# 516   517  Exodus: Gods and Kings    Action,Adventure,Drama
# 521   522           The Counselor      Crime,Drama,Thriller
# 530   531             A Good Year      Comedy,Drama,Romance
# 737   738            Body of Lies      Action,Drama,Romance
#
#                                            Description      Director  \
# 1    Following clues to the origin of mankind, a te...  Ridley Scott
# 102  An astronaut becomes stranded on Mars after hi...  Ridley Scott
# 387  In 12th century England, Robin and his band of...  Ridley Scott
# 470  In 1970s America, a detective works to bring d...  Ridley Scott
# 516  The defiant leader Moses rises up against the ...  Ridley Scott
# ...

# %%
movies[(movies['Year']>=2012) &(movies['Year']<2016)]
# Out:
#      Rank                                       Title  \
# 0       1                     Guardians of the Galaxy
# 1       2                                  Prometheus
# 26     27                     Bahubali: The Beginning
# 36     37                                Interstellar
# 50     51  Star Wars: Episode VII - The Force Awakens
# ..    ...                                         ...
# 983   984                               Let's Be Cops
# 984   985                                         Max
# 987   988                                Endless Love
# 989   990                                       Selma
# 998   999                                Search Party
#
#                         Genre  \
# 0     Action,Adventure,Sci-Fi
# 1    Adventure,Mystery,Sci-Fi
# 26     Action,Adventure,Drama
# 36     Adventure,Drama,Sci-Fi
# 50   Action,Adventure,Fantasy
# ..                        ...
# 983                    Comedy
# 984          Adventure,Family
# 987             Drama,Romance
# ...

# %%
#FOR MOVIE DATA
movie=pd.read_csv("Movie-Data.csv")
movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movie.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
movie.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
rev=movie['Revenue (Millions)']
rev
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
maxR=max(rev)
maxR
# Out:
# 936.63

# %%
minR=min(rev)
minR
# Out:
# 0.0

# %%
a=movie[movie['Revenue (Millions)']==0.0]
a
# Out:
#      Rank             Title                 Genre  \
# 231   232  A Kind of Murder  Crime,Drama,Thriller
#
#                                            Description      Director  \
# 231  In 1960s New York, Walter Stackhouse is a succ...  Andy Goddard
#
#                                                 Actors    Year  \
# 231  Patrick Wilson, Jessica Biel, Haley Bennett, V...  2016.0
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 231                 95     5.2   3305                 0.0       50.0

# %%
years=movie['Year']
years
# Out:
# 0      2014.0
# 1      2012.0
# 2      2016.0
# 3         NaN
# 4      2016.0
#         ...
# 995       NaN
# 996       NaN
# 997    2008.0
# 998    2014.0
# 999    2016.0
# Name: Year, Length: 1000, dtype: float64

# %%
uyear=years.unique()
uyear
# Out:
# array([2014., 2012., 2016.,   nan, 2015., 2007., 2011., 2008., 2006.,
#        2009., 2010., 2013.])

# %%
uyear.sort()

# %%
uyear
# Out:
# array([2006., 2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014.,
#        2015., 2016.,   nan])

# %%
revof2006=movie[movie['Year']==2006]
revof2006
# Out:
#      Rank                                        Title  \
# 64     65                                 The Prestige
# 78     79   Pirates of the Caribbean: Dead Man's Chest
# 99    100                                 The Departed
# 113   114                                          300
# 164   165                                Casino Royale
# 221   222                                         Cars
# 230   231                              Pan's Labyrinth
# 232   233                                   Apocalypto
# 246   247                              Children of Men
# 297   298                        The Devil Wears Prada
# 308   309        The Fast and the Furious: Tokyo Drift
# 320   321                                      Step Up
# 445   446                                  Silent Hill
# 471   472                             Marie Antoinette
# 476   477                          The Lives of Others
# 530   531                                  A Good Year
# ...

# %%
revof2006.sum()
# Out:
# Rank                                                              25894
# Title                 The PrestigePirates of the Caribbean: Dead Man...
# Genre                 Drama,Mystery,Sci-FiAction,Adventure,FantasyCr...
# Description           Two stage magicians engage in competitive one-...
# Director              Christopher NolanGore VerbinskiMartin Scorsese...
# Actors                Christian Bale, Hugh Jackman, Scarlett Johanss...
# Year                                                              88264
# Runtime (Minutes)                                                  5317
# Rating                                                            313.5
# Votes                                                          11848758
# Revenue (Millions)                                              3624.46
# Metascore                                                          2641
# dtype: object

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
car=pd.read_csv("cars.csv")
car
# Out:
#      Unnamed: 0  price      brand    model  year   title_status  mileage  \
# 0             0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1             1   2899       ford       se  2011  clean vehicle   190552
# 2             2   5350      dodge      mpv  2018  clean vehicle    39590
# 3             3  25000       ford     door  2014  clean vehicle    64146
# 4             4  27700  chevrolet     1500  2018  clean vehicle     6654
# ..          ...    ...        ...      ...   ...            ...      ...
# 172         172   5470      dodge      mpv  2018  clean vehicle    39721
# 173         173  14600       ford     door  2014  clean vehicle    75785
# 174         174  24502  chevrolet     1500  2016  clean vehicle    33624
# 175         175  15110       ford     door  2017  clean vehicle    42289
# 176         176   7900       ford     door  2014  clean vehicle    79422
#
#       color                  vin        lot         state country  \
# ...

# %%
car.head(10)
# Out:
#    Unnamed: 0  price      brand    model  year   title_status  mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1           1   2899       ford       se  2011  clean vehicle   190552
# 2           2   5350      dodge      mpv  2018  clean vehicle    39590
# 3           3  25000       ford     door  2014  clean vehicle    64146
# 4           4  27700  chevrolet     1500  2018  clean vehicle     6654
# 5           5   5700      dodge      mpv  2018  clean vehicle    45561
# 6           6   7300  chevrolet       pk  2010  clean vehicle   149050
# 7           7  13350        gmc     door  2017  clean vehicle    23525
# 8           8  14600  chevrolet   malibu  2018  clean vehicle     9371
# 9           9   5250       ford      mpv  2017  clean vehicle    63418
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# ...

# %%
car.shape
# Out:
# (177, 13)

# %%
car.size
# Out:
# 2301

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    177 non-null    int64
#  1   price         177 non-null    int64
#  2   brand         177 non-null    object
#  3   model         177 non-null    object
#  4   year          177 non-null    int64
#  5   title_status  177 non-null    object
#  6   mileage       177 non-null    int64
#  7   color         177 non-null    object
#  8   vin           177 non-null    object
#  9   lot           177 non-null    int64
#  10  state         177 non-null    object
#  11  country       177 non-null    object
#  12  condition     177 non-null    object
# dtypes: int64(5), object(8)
# memory usage: 18.1+ KB

# %%
car.columns
# Out:
# Index(['Unnamed: 0', 'price', 'brand', 'model', 'year', 'title_status',
#        'mileage', 'color', 'vin', 'lot', 'state', 'country', 'condition'],
#       dtype='object')

# %%
Brand=car['brand']
Brand
# Out:
# 0         toyota
# 1           ford
# 2          dodge
# 3           ford
# 4      chevrolet
#          ...
# 172        dodge
# 173         ford
# 174    chevrolet
# 175         ford
# 176         ford
# Name: brand, Length: 177, dtype: object

# %%
Brand.unique()
# Out:
# array(['toyota', 'ford', 'dodge', 'chevrolet', 'gmc', 'chrysler', 'kia',
#        'buick', 'infiniti', 'mercedes-benz', 'jeep', 'bmw', 'cadillac'],
#       dtype=object)

# %%
bprice=car['price']
bprice
# Out:
# 0       6300
# 1       2899
# 2       5350
# 3      25000
# 4      27700
#        ...
# 172     5470
# 173    14600
# 174    24502
# 175    15110
# 176     7900
# Name: price, Length: 177, dtype: int64

# %%
for brand in car['brand'].unique():
    bdf = car[car['brand'] == brand]
    mean_price = bdf['price'].mean()
    print(f"The car brand is {brand}: Mean price is {mean_price}")
# Out:
# The car brand is toyota: Mean price is 6300.0
# The car brand is ford: Mean price is 14645.327586206897
# The car brand is dodge: Mean price is 8581.6
# The car brand is chevrolet: Mean price is 24665.266666666666
# The car brand is gmc: Mean price is 12711.176470588236
# The car brand is chrysler: Mean price is 18332.30769230769
# The car brand is kia: Mean price is 11333.333333333334
# The car brand is buick: Mean price is 20017.5
# The car brand is infiniti: Mean price is 18500.0
# The car brand is mercedes-benz: Mean price is 16600.0
# The car brand is jeep: Mean price is 17955.555555555555
# The car brand is bmw: Mean price is 37566.666666666664
# The car brand is cadillac: Mean price is 28851.333333333332

# %%
car.columns
# Out:
# Index(['Unnamed: 0', 'price', 'brand', 'model', 'year', 'title_status',
#        'mileage', 'color', 'vin', 'lot', 'state', 'country', 'condition'],
#       dtype='object')

# %%
blackcar=car[car['color']=='black']
blackcar
# Out:
#      Unnamed: 0  price      brand     model  year   title_status  mileage  \
# 0             0   6300     toyota   cruiser  2008  clean vehicle   274117
# 6             6   7300  chevrolet        pk  2010  clean vehicle   149050
# 9             9   5250       ford       mpv  2017  clean vehicle    63418
# 12           12  31900  chevrolet      1500  2018  clean vehicle    22909
# 14           14  20700       ford      door  2013  clean vehicle   100757
# 21           21   7300        kia     forte  2018  clean vehicle    38823
# 22           22  15000  chevrolet      door  2015  clean vehicle    61578
# 35           35  11900        gmc      door  2017  clean vehicle    27965
# 44           44  55000       ford       srw  2017  clean vehicle    15273
# 45           45  12520        gmc      door  2017  clean vehicle    28972
# 49           49  54000       ford       srw  2017  clean vehicle    26241
# 62           62  17800  chevrolet      door  2017  clean vehicle    52435
# ...

# %% [raw]
# len(Blackcar)

# %%
len(blackcar)
# Out:
# 43

# %%
car
# Out:
#      Unnamed: 0  price      brand    model  year   title_status  mileage  \
# 0             0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1             1   2899       ford       se  2011  clean vehicle   190552
# 2             2   5350      dodge      mpv  2018  clean vehicle    39590
# 3             3  25000       ford     door  2014  clean vehicle    64146
# 4             4  27700  chevrolet     1500  2018  clean vehicle     6654
# ..          ...    ...        ...      ...   ...            ...      ...
# 172         172   5470      dodge      mpv  2018  clean vehicle    39721
# 173         173  14600       ford     door  2014  clean vehicle    75785
# 174         174  24502  chevrolet     1500  2016  clean vehicle    33624
# 175         175  15110       ford     door  2017  clean vehicle    42289
# 176         176   7900       ford     door  2014  clean vehicle    79422
#
#       color                  vin        lot         state country  \
# ...

# %%
x=car['price']
y=car['brand']
plt.plot(x,y)
plt.show()

# %%
brands=car['brand']
brands
# Out:
# 0         toyota
# 1           ford
# 2          dodge
# 3           ford
# 4      chevrolet
#          ...
# 172        dodge
# 173         ford
# 174    chevrolet
# 175         ford
# 176         ford
# Name: brand, Length: 177, dtype: object

# %%
ubrand=brands.unique()
ubrand
# Out:
# array(['toyota', 'ford', 'dodge', 'chevrolet', 'gmc', 'chrysler', 'kia',
#        'buick', 'infiniti', 'mercedes-benz', 'jeep', 'bmw', 'cadillac'],
#       dtype=object)

# %%
for brand in car['brand'].unique():
    bdf=car[car['brand']==brand]
    mean_price=car['price'].mean()
    print(f"The car is of {brand}: Mean price is{mean_price}")
# Out:
# The car is of toyota: Mean price is17121.751412429378
# The car is of ford: Mean price is17121.751412429378
# The car is of dodge: Mean price is17121.751412429378
# The car is of chevrolet: Mean price is17121.751412429378
# The car is of gmc: Mean price is17121.751412429378
# The car is of chrysler: Mean price is17121.751412429378
# The car is of kia: Mean price is17121.751412429378
# The car is of buick: Mean price is17121.751412429378
# The car is of infiniti: Mean price is17121.751412429378
# The car is of mercedes-benz: Mean price is17121.751412429378
# The car is of jeep: Mean price is17121.751412429378
# The car is of bmw: Mean price is17121.751412429378
# The car is of cadillac: Mean price is17121.751412429378

# %% [raw]
# car.tail()

# %%
car.tail()
# Out:
#      Unnamed: 0  price      brand model  year   title_status  mileage  color  \
# 172         172   5470      dodge   mpv  2018  clean vehicle    39721  black
# 173         173  14600       ford  door  2014  clean vehicle    75785  black
# 174         174  24502  chevrolet  1500  2016  clean vehicle    33624  black
# 175         175  15110       ford  door  2017  clean vehicle    42289  white
# 176         176   7900       ford  door  2014  clean vehicle    79422  white
#
#                      vin        lot         state country      condition
# 172    3c4pdcgg9jt216280  167656495       florida     usa  16 hours left
# 173    1fm5k8f81egb23411  167756284  pennsylvania     usa  21 hours left
# 174    3gcuknec6gg150809  167765812      michigan     usa  20 hours left
# 175    1ft7w2bt7hec67263  167656516         texas     usa    2 days left
# 176    1fmcu0g9xeud52262  167756290      new york     usa  21 hours left

# %%
car
# Out:
#      Unnamed: 0  price      brand    model  year   title_status  mileage  \
# 0             0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1             1   2899       ford       se  2011  clean vehicle   190552
# 2             2   5350      dodge      mpv  2018  clean vehicle    39590
# 3             3  25000       ford     door  2014  clean vehicle    64146
# 4             4  27700  chevrolet     1500  2018  clean vehicle     6654
# ..          ...    ...        ...      ...   ...            ...      ...
# 172         172   5470      dodge      mpv  2018  clean vehicle    39721
# 173         173  14600       ford     door  2014  clean vehicle    75785
# 174         174  24502  chevrolet     1500  2016  clean vehicle    33624
# 175         175  15110       ford     door  2017  clean vehicle    42289
# 176         176   7900       ford     door  2014  clean vehicle    79422
#
#       color                  vin        lot         state country  \
# ...

# %%
maxcar=car[car['year']==2017]
maxcar
# Out:
#      Unnamed: 0  price      brand  model  year   title_status  mileage  \
# 7             7  13350        gmc   door  2017  clean vehicle    23525
# 9             9   5250       ford    mpv  2017  clean vehicle    63418
# 11           11  12920        gmc    mpv  2017  clean vehicle    39650
# 13           13   5430   chrysler  wagon  2017  clean vehicle   138650
# 15           15  12710        gmc   door  2017  clean vehicle    25747
# ..          ...    ...        ...    ...   ...            ...      ...
# 137         137  19500   chrysler    300  2017  clean vehicle    31311
# 138         138  32012  chevrolet   1500  2017  clean vehicle    46091
# 142         142  31802  chevrolet   2500  2017  clean vehicle    19845
# 145         145  28402  chevrolet   1500  2017  clean vehicle    31234
# 175         175  15110       ford   door  2017  clean vehicle    42289
#
#       color                  vin        lot       state country      condition
# ...

# %%
car.duplicated().sum()
# Out:
# 0

# %%
car.isnull().sum()
# Out:
# Unnamed: 0      0
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           0
# vin             0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64

# %%
car
# Out:
#      Unnamed: 0  price      brand    model  year   title_status  mileage  \
# 0             0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1             1   2899       ford       se  2011  clean vehicle   190552
# 2             2   5350      dodge      mpv  2018  clean vehicle    39590
# 3             3  25000       ford     door  2014  clean vehicle    64146
# 4             4  27700  chevrolet     1500  2018  clean vehicle     6654
# ..          ...    ...        ...      ...   ...            ...      ...
# 172         172   5470      dodge      mpv  2018  clean vehicle    39721
# 173         173  14600       ford     door  2014  clean vehicle    75785
# 174         174  24502  chevrolet     1500  2016  clean vehicle    33624
# 175         175  15110       ford     door  2017  clean vehicle    42289
# 176         176   7900       ford     door  2014  clean vehicle    79422
#
#       color                  vin        lot         state country  \
# ...

# %%
set_2017=car[car['year']==2017]
set_2017
# Out:
#      Unnamed: 0  price      brand  model  year   title_status  mileage  \
# 7             7  13350        gmc   door  2017  clean vehicle    23525
# 9             9   5250       ford    mpv  2017  clean vehicle    63418
# 11           11  12920        gmc    mpv  2017  clean vehicle    39650
# 13           13   5430   chrysler  wagon  2017  clean vehicle   138650
# 15           15  12710        gmc   door  2017  clean vehicle    25747
# ..          ...    ...        ...    ...   ...            ...      ...
# 137         137  19500   chrysler    300  2017  clean vehicle    31311
# 138         138  32012  chevrolet   1500  2017  clean vehicle    46091
# 142         142  31802  chevrolet   2500  2017  clean vehicle    19845
# 145         145  28402  chevrolet   1500  2017  clean vehicle    31234
# 175         175  15110       ford   door  2017  clean vehicle    42289
#
#       color                  vin        lot       state country      condition
# ...

# %%
set_2017_brand=set_2017.groupby('brand')['Number of cars'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-181-645cc27d54d0> in <module>()
# ----> 1 set_2017_brand=set_2017.groupby('brand')['Number of cars'].sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1608                 stacklevel=2,
#    1609             )
# -> 1610         return super().__getitem__(key)
#    1611
#    1612     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     226         else:
#     227             if key not in self.obj:
# --> 228                 raise KeyError(f"Column not found: {key}")
#     229             return self._gotitem(key, ndim=1)
#     230
#
# KeyError: 'Column not found: Number of cars'

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
iri=pd.read_csv('iris.csv')
iri
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
varieties=iri['variety']
varieties
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: object

# %%
varieties.unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
vardict= {}
for variety in varieties:
    counts=len(iri[iri['variety']==variety])
    vardict[variety]=counts
    print(f" {variety}:{counts}")
# Out:
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Setosa:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
#  Versicolor:50
# ...

# %%
vardict = {}
for variety in varieties:
    counts = len(iri[iri['variety']==variety])
    vardict[variety]=counts
    print(f"{variety} : {counts}")
# Out:
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Setosa : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# Versicolor : 50
# ...

# %%
iri.duplicated().sum()
# Out:
# 1

# %%
iri.drop_duplicates(inplace=True)

# %%
iri.duplicated().sum()
# Out:
# 0

# %%
iri.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
flight=pd.read_csv("flight.csv")

# %%
flight
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1      1455            1459         -4      1655
# 1    2013      1    1      1455            1500         -5      1753
# 2    2013      1    1      1456            1500         -4      1649
# 3    2013      1    1      1456            1455          1      1830
# 4    2013      1    1      1457            1500         -3      1758
# ..    ...    ...  ...       ...             ...        ...       ...
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
flight.head(10)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1      1455            1459         -4      1655
# 1  2013      1    1      1455            1500         -5      1753
# 2  2013      1    1      1456            1500         -4      1649
# 3  2013      1    1      1456            1455          1      1830
# 4  2013      1    1      1457            1500         -3      1758
# 5  2013      1    1      1457            1500         -3      1652
# 6  2013      1    1      1458            1500         -2      1658
# 7  2013      1    1      1459            1501         -2      1651
# 8  2013      1    1      1459            1454          5      1750
# 9  2013      1    1      1500            1459          1      1809
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0            1645       10.0      B6    1053  N203JB    JFK  PIT      87.0
# 1            1810      -17.0      DL    1997  N997DL    LGA  PBI     152.0
# ...

# %%
flight.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')

# %%
flight1=flight[['dep_time','dep_delay']]
flight1
# Out:
#      dep_time  dep_delay
# 0        1455         -4
# 1        1455         -5
# 2        1456         -4
# 3        1456          1
# 4        1457         -3
# ..        ...        ...
# 194      1758         -2
# 195      1758         -2
# 196      1758          9
# 197      1759          0
# 198      1800          0
#
# [199 rows x 2 columns]

# %%
flight.duplicated().sum()
# Out:
# 0

# %%
flight.duplicated().value_counts()
# Out:
# False    199
# dtype: int64

# %%
flight.isnull().sum()
# Out:
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         3
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          3
# distance          0
# hour              0
# minute            0
# time_hour         0
# dtype: int64

# %%
arrd=flight['arr_delay']
arrd
# Out:
# 0      10.0
# 1     -17.0
# 2      17.0
# 3      17.0
# 4     -17.0
#        ...
# 194   -12.0
# 195    -5.0
# 196    37.0
# 197     8.0
# 198    -6.0
# Name: arr_delay, Length: 199, dtype: float64

# %%
a=arrd.mean()
a
# Out:
# 15.183673469387756

# %%
arrd.fillna(a,inplace=True)
arrd.isnull().sum()
# Out:
# 0

# %%
diamond=pd.read_csv('diamond.csv')
diamond
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52
#
# [199 rows x 10 columns]

# %%
diamond.tail()
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 194    0.7  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195    0.7  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196    0.7  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197    0.7  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198    0.7    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52

# %%
import pandas as pd
diamond=pd.read_csv('diamond.csv')
diamond
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52
#
# [199 rows x 10 columns]

# %%
diamond.shape
# Out:
# (199, 10)

# %%
drop_diamond=diamond.drop(['x','y','z'],axis=1)
drop_diamond
# Out:
#      carat      cut color clarity  depth  table  price
# 0     0.23    Ideal     E     SI2   61.5   55.0    326
# 1     0.21  Premium     E     SI1   59.8   61.0    326
# 2     0.23     Good     E     VS1   56.9   65.0    327
# 3     0.29  Premium     I     VS2   62.4   58.0    334
# 4     0.31     Good     J     SI2   63.3   58.0    335
# ..     ...      ...   ...     ...    ...    ...    ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777
# 195   0.70  Premium     E     SI1   62.7   59.0   2777
# 196   0.70  Premium     E     SI1   61.0   57.0   2777
# 197   0.70  Premium     E     SI1   61.0   58.0   2777
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777
#
# [199 rows x 7 columns]

# %%
diamond.shape
# Out:
# (199, 10)
